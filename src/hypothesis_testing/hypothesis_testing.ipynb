# %%
import pandas as pd
import numpy as np
import collections
import os

# %%
data = pd.read_csv('../../cleaned_dataset/personblity_emotion_efficiency.csv')

# %%
data
# Out:
#      user_id  Efficiency  Enjoyment  Boredom  Confidence  Anxiety Personality  \
# 0         33        20.0          3        2           2        2           S
# 1         44        60.0          5        1           5        1           C
# 2         76        30.0          3        2           3        2           S
# 3         77        30.0          5        2           4        3           S
# 4         78        30.0          4        3           2        3           D
# ..       ...         ...        ...      ...         ...      ...         ...
# 292      770       180.0          5        1           5        1           I
# 293      773      1440.0          3        2           4        1           I
# 294      776        60.0          5        1           3        3           S
# 295      782       240.0          5        1           3        5           D
# 296      784        30.0          3        3           4        2           I
#
#      group_type
# ...

# %%
# Perform hypothesis testing
results = []
emotions_to_test = ['Enjoyment', 'Boredom', 'Confidence', 'Anxiety']
groups = data['group_type'].unique()
personality= data['Personality'].unique()
personality[1]
# Out:
# 'C'

# %%
subset = data[(data['group_type'] == 1) & (data['Personality'] == personality[0])]

emotion_data = [subset[emotion].dropna() for emotion in emotions_to_test]

# %%
len(emotion_data)
emotion_data[0].values
# Out:
# array([5, 4, 5, 4, 3, 3, 4, 4, 4, 3, 5, 3, 4, 4, 5, 5, 2, 4, 4, 2, 5, 4,
#        4, 3, 4, 4, 4, 3, 3, 5, 5])

# %%
# Out:
#   Cell In[42], line 1
#     *emotion_data
#     ^
# SyntaxError: can't use starred expression here

# %%
data_g = data.loc[data.group_type==2]
data_s = data.loc[data.group_type==1]

# %%
from scipy import stats

# %%
#########################################
### group Emotion vs personality  ####
#########################################


#########################################
### group Enjoyment vs personality  ####
#########################################
personalityS = data_g.loc[data.Personality=='S']
personalityC = data_g.loc[data.Personality=='C']
personalityI = data_g.loc[data.Personality=='I']
personalityD = data_g.loc[data.Personality=='D']



result = stats.kruskal(personalityS.Enjoyment.tolist(),personalityC.Enjoyment.tolist(),personalityI.Enjoyment.tolist(),personalityD.Enjoyment.tolist())
 
# Print the result
print(result)
print('personality influences enjoyment')

#########################################
### group boredom vs personality  #####
#########################################

result = stats.kruskal(personalityS.Boredom.tolist(),personalityC.Boredom.tolist(),personalityI.Boredom.tolist(),personalityD.Boredom.tolist())
 
# Print the result
print(result)
print('personality influences Boredom ')

#########################################
### group Confidence vs personality  ####
#########################################

result = stats.kruskal(personalityS.Confidence.tolist(),personalityC.Confidence.tolist(),personalityI.Confidence.tolist(),personalityD.Confidence.tolist())
 
# Print the result
print(result)
print('personality influences Confidence')

#########################################
### group Anxiety vs personality  ####
#########################################

result = stats.kruskal(personalityS.Anxiety.tolist(),personalityC.Anxiety.tolist(),personalityI.Anxiety.tolist(),personalityD.Anxiety.tolist())
 
# Print the result
print(result)
print('personality influences Anxiety')
# Out:
# KruskalResult(statistic=3.1419524783309583, pvalue=0.37025247717695237)
# personality influences enjoyment
# KruskalResult(statistic=3.2253127260168055, pvalue=0.35817372465755487)
# personality influences Boredom
# KruskalResult(statistic=0.969016597997002, pvalue=0.8087484239610482)
# personality influences Confidence
# KruskalResult(statistic=2.182951419366773, pvalue=0.5353142119408634)
# personality influences Anxiety

# %%
#########################################
### group Emotion vs efficiency      ####
#########################################


#########################################
### group Enjoyment vs efficiency  ####
#########################################
efficiency_1 = data_g.loc[data.Enjoyment==1].Efficiency.tolist()
efficiency_2 = data_g.loc[data.Enjoyment==2].Efficiency.tolist()
efficiency_3 = data_g.loc[data.Enjoyment==3].Efficiency.tolist()
efficiency_4 = data_g.loc[data.Enjoyment==4].Efficiency.tolist()
efficiency_5 = data_g.loc[data.Enjoyment==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('emjoyment influences efficiency')

#########################################
### group Boredom vs efficiency  ########
#########################################
efficiency_1 = data_g.loc[data.Boredom==1].Efficiency.tolist()
efficiency_2 = data_g.loc[data.Boredom==2].Efficiency.tolist()
efficiency_3 = data_g.loc[data.Boredom==3].Efficiency.tolist()
efficiency_4 = data_g.loc[data.Boredom==4].Efficiency.tolist()
efficiency_5 = data_g.loc[data.Boredom==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('Boredom influences efficiency')

#########################################
### group Confidence vs efficiency  ####
#########################################
efficiency_1 = data_g.loc[data.Confidence==1].Efficiency.tolist()
efficiency_2 = data_g.loc[data.Confidence==2].Efficiency.tolist()
efficiency_3 = data_g.loc[data.Confidence==3].Efficiency.tolist()
efficiency_4 = data_g.loc[data.Confidence==4].Efficiency.tolist()
efficiency_5 = data_g.loc[data.Confidence==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('Confidence influences efficiency')

#########################################
### group Enjoyment vs efficiency    ####
#########################################
efficiency_1 = data_g.loc[data.Anxiety==1].Efficiency.tolist()
efficiency_2 = data_g.loc[data.Anxiety==2].Efficiency.tolist()
efficiency_3 = data_g.loc[data.Anxiety==3].Efficiency.tolist()
efficiency_4 = data_g.loc[data.Anxiety==4].Efficiency.tolist()
efficiency_5 = data_g.loc[data.Anxiety==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('Anxiety influences efficiency')
# Out:
# KruskalResult(statistic=5.735633567746689, pvalue=0.2197803644860194)
# emjoyment influences efficiency
# KruskalResult(statistic=4.689567352041045, pvalue=0.32065751548591687)
# Boredom influences efficiency
# KruskalResult(statistic=5.271022075607422, pvalue=0.2606018934504212)
# Confidence influences efficiency
# KruskalResult(statistic=2.127190958295, pvalue=0.7123786910419623)
# Anxiety influences efficiency

# %%
########################################
### group personality vs efficiency ####
########################################

eS = personalityS.Efficiency
eC = personalityC.Efficiency
eI = personalityI.Efficiency
eD = personalityD.Efficiency

result = stats.kruskal(eS,eC,eI,eD)
 
# Print the result
print(result)
print("personality has relation to efficiency (team)")
# Out:
# KruskalResult(statistic=2.897047865807643, pvalue=0.40777224963046865)
# personality has relation to efficiency (team)

# %%
personalityS = data_s.loc[data.Personality=='S']
personalityC = data_s.loc[data.Personality=='C']
personalityI = data_s.loc[data.Personality=='I']
personalityD = data_s.loc[data.Personality=='D']

# %%
#########################################
### solo Emotion vs personality  ####
#########################################




#########################################
### solo Enjoyment vs personality  ####
#########################################

result = stats.kruskal(personalityS.Enjoyment.tolist(),personalityC.Enjoyment.tolist(),personalityI.Enjoyment.tolist(),personalityD.Enjoyment.tolist())
 
# Print the result
print(result)
print('personality influences enjoyment')

#########################################
### solo boredom vs personality  #####
#########################################

result = stats.kruskal(personalityS.Boredom.tolist(),personalityC.Boredom.tolist(),personalityI.Boredom.tolist(),personalityD.Boredom.tolist())
 
# Print the result
print(result)
print('personality influences Boredom ')

#########################################
### solo Confidence vs personality  ####
#########################################

result = stats.kruskal(personalityS.Confidence.tolist(),personalityC.Confidence.tolist(),personalityI.Confidence.tolist(),personalityD.Confidence.tolist())
 
# Print the result
print(result)
print('personality influences Confidence')

#########################################
### solo Anxiety vs personality  ####
#########################################

result = stats.kruskal(personalityS.Anxiety.tolist(),personalityC.Anxiety.tolist(),personalityI.Anxiety.tolist(),personalityD.Anxiety.tolist())
 
# Print the result
print(result)
print('personality influences Anxiety')
# Out:
# KruskalResult(statistic=2.0863728047201033, pvalue=0.5546745535847462)
# personality influences enjoyment
# KruskalResult(statistic=6.457775011236623, pvalue=0.09134271050818495)
# personality influences Boredom
# KruskalResult(statistic=2.269821301395822, pvalue=0.5183269849717174)
# personality influences Confidence
# KruskalResult(statistic=0.19750097426127564, pvalue=0.9779917142849993)
# personality influences Anxiety

# %%
#########################################
### solo Emotion vs efficiency      ####
#########################################


#########################################
### solo Enjoyment vs efficiency  ####
#########################################
efficiency_1 = data_s.loc[data.Enjoyment==1].Efficiency.tolist()
efficiency_2 = data_s.loc[data.Enjoyment==2].Efficiency.tolist()
efficiency_3 = data_s.loc[data.Enjoyment==3].Efficiency.tolist()
efficiency_4 = data_s.loc[data.Enjoyment==4].Efficiency.tolist()
efficiency_5 = data_s.loc[data.Enjoyment==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('emjoyment influences efficiency')

#########################################
### solo Boredom vs efficiency  ########
#########################################
efficiency_1 = data_s.loc[data.Boredom==1].Efficiency.tolist()
efficiency_2 = data_s.loc[data.Boredom==2].Efficiency.tolist()
efficiency_3 = data_s.loc[data.Boredom==3].Efficiency.tolist()
efficiency_4 = data_s.loc[data.Boredom==4].Efficiency.tolist()
efficiency_5 = data_s.loc[data.Boredom==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('Boredom does not influences efficiency')

#########################################
### solo Confidence vs efficiency  ####
#########################################
efficiency_1 = data_s.loc[data.Confidence==1].Efficiency.tolist()
efficiency_2 = data_s.loc[data.Confidence==2].Efficiency.tolist()
efficiency_3 = data_s.loc[data.Confidence==3].Efficiency.tolist()
efficiency_4 = data_s.loc[data.Confidence==4].Efficiency.tolist()
efficiency_5 = data_s.loc[data.Confidence==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('Confidence influences efficiency')

#########################################
### solo Enjoyment vs efficiency    ####
#########################################
efficiency_1 = data_s.loc[data.Anxiety==1].Efficiency.tolist()
efficiency_2 = data_s.loc[data.Anxiety==2].Efficiency.tolist()
efficiency_3 = data_s.loc[data.Anxiety==3].Efficiency.tolist()
efficiency_4 = data_s.loc[data.Anxiety==4].Efficiency.tolist()
efficiency_5 = data_s.loc[data.Anxiety==5].Efficiency.tolist()

result = stats.kruskal(efficiency_1,efficiency_2,efficiency_3,efficiency_4,efficiency_5)
 
# Print the result
print(result)
print('Anxiety influences efficiency')
# Out:
# KruskalResult(statistic=4.220435704381089, pvalue=0.3769943495728584)
# emjoyment influences efficiency
# KruskalResult(statistic=11.494221383925119, pvalue=0.021536710724899422)
# Boredom does not influences efficiency
# KruskalResult(statistic=4.687895045632326, pvalue=0.3208455190822275)
# Confidence influences efficiency
# KruskalResult(statistic=2.28575213752675, pvalue=0.6833642964502666)
# Anxiety influences efficiency

# %%
########################################
### solo personality vs efficiency ####
########################################

eS = personalityS.Efficiency
eC = personalityC.Efficiency
eI = personalityI.Efficiency
eD = personalityD.Efficiency

result = stats.kruskal(eS,eC,eI,eD)
 
# Print the result
print(result)
print("personality has relation to efficiency (solo)")
# Out:
# KruskalResult(statistic=6.372582290762141, pvalue=0.09482528476292545)
# personality has relation to efficiency (solo)

# %%
d = pd.read_csv('out32_with_creativity.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 d = pd.read_csv('out32_with_creativity.csv')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
d
# Out:
#      index  user_id  time  Enjoyment  Boredom  Confidence  Anxiety  \
# 0        0       33    20          3        2           2        2
# 1        1       44    60          5        1           5        1
# 2        2       76    30          3        2           3        2
# 3        3       77    30          5        2           4        3
# 4        4       78    30          4        3           2        3
# ..     ...      ...   ...        ...      ...         ...      ...
# 222    222      589    15          4        1           3        5
# 223    223      590    35          4        2           4        3
# 224    224      591    45          5        1           5        1
# 225    225      592    75          5        1           5        2
# 226    226      594    35          4        2           4        3
#
#     Personality  group_type  Novelty  Usefulness
# 0             S           2    1.500    3.250000
# 1             C           2    3.250    3.750000
# ...

# %%
data_g = d.loc[d.group_type==2]
data_s = d.loc[d.group_type==1]

# %%
personalityS = data_g.loc[data.Personality=='S']
personalityC = data_g.loc[data.Personality=='C']
personalityI = data_g.loc[data.Personality=='I']
personalityD = data_g.loc[data.Personality=='D']

# %%
#####################################
### group personality vs novelty ####
#####################################
result = stats.kruskal(personalityS.Novelty,personalityC.Novelty,personalityI.Novelty,personalityD.Novelty)
 
# Print the result
print(result)
print("personality does influence Novelty (group)")


#######################################
### Group personality vs usefulness ###
#######################################
result = stats.kruskal(personalityS.Usefulness,personalityC.Usefulness,personalityI.Usefulness,personalityD.Usefulness)
 
# Print the result
print(result)
print("personality does not influence Usefulness (group)")
# Out:
# KruskalResult(statistic=0.5134450773557827, pvalue=0.9159278123397111)
# personality does influence Novelty (group)
# KruskalResult(statistic=8.186865050230951, pvalue=0.04230357961325767)
# personality does not influence Usefulness (group)

# %%
#####################################
### group Emotion vs novelty ########
#####################################


#####################################
### group Enjoyment vs novelty ######
#####################################
novelty_1 = data_g.loc[data.Enjoyment==1].Novelty.tolist()
novelty_2 = data_g.loc[data.Enjoyment==2].Novelty.tolist()
novelty_3 = data_g.loc[data.Enjoyment==3].Novelty.tolist()
novelty_4 = data_g.loc[data.Enjoyment==4].Novelty.tolist()
novelty_5 = data_g.loc[data.Enjoyment==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Enjoyment does influences novelty')

#####################################
### group Boredom vs novelty ######
#####################################
novelty_1 = data_g.loc[data.Boredom==1].Novelty.tolist()
novelty_2 = data_g.loc[data.Boredom==2].Novelty.tolist()
novelty_3 = data_g.loc[data.Boredom==3].Novelty.tolist()
novelty_4 = data_g.loc[data.Boredom==4].Novelty.tolist()
novelty_5 = data_g.loc[data.Boredom==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Boredom does influences novelty')


#####################################
### group Enjoyment vs novelty ######
#####################################
novelty_1 = data_g.loc[data.Confidence==1].Novelty.tolist()
novelty_2 = data_g.loc[data.Confidence==2].Novelty.tolist()
novelty_3 = data_g.loc[data.Confidence==3].Novelty.tolist()
novelty_4 = data_g.loc[data.Confidence==4].Novelty.tolist()
novelty_5 = data_g.loc[data.Confidence==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Confidence does influences novelty')

#####################################
### group Enjoyment vs novelty ######
#####################################
novelty_1 = data_g.loc[data.Anxiety==1].Novelty.tolist()
novelty_2 = data_g.loc[data.Anxiety==2].Novelty.tolist()
novelty_3 = data_g.loc[data.Anxiety==3].Novelty.tolist()
novelty_4 = data_g.loc[data.Anxiety==4].Novelty.tolist()
novelty_5 = data_g.loc[data.Anxiety==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Anxiety does influences novelty')
# Out:
# KruskalResult(statistic=3.3578882545235884, pvalue=0.4998129289165574)
# Enjoyment does influences novelty
# KruskalResult(statistic=7.627367579245108, pvalue=0.10622230775970445)
# Boredom does influences novelty
# KruskalResult(statistic=5.613854621384831, pvalue=0.22990136104557465)
# Confidence does influences novelty
# KruskalResult(statistic=2.409476879573125, pvalue=0.660915317969107)
# Anxiety does influences novelty

# %%
#####################################
### group Emotion vs Usefulness #####
#####################################


#####################################
### group Enjoyment vs Usefulness ###
#####################################
novelty_1 = data_g.loc[data.Enjoyment==1].Usefulness.tolist()
novelty_2 = data_g.loc[data.Enjoyment==2].Usefulness.tolist()
novelty_3 = data_g.loc[data.Enjoyment==3].Usefulness.tolist()
novelty_4 = data_g.loc[data.Enjoyment==4].Usefulness.tolist()
novelty_5 = data_g.loc[data.Enjoyment==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Enjoyment does influences Usefulness')

#####################################
### group Boredom vs Usefulness #####
#####################################
novelty_1 = data_g.loc[data.Boredom==1].Usefulness.tolist()
novelty_2 = data_g.loc[data.Boredom==2].Usefulness.tolist()
novelty_3 = data_g.loc[data.Boredom==3].Usefulness.tolist()
novelty_4 = data_g.loc[data.Boredom==4].Usefulness.tolist()
novelty_5 = data_g.loc[data.Boredom==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Boredom does influences Usefulness')


#####################################
### group Enjoyment vs Usefulness ###
#####################################
novelty_1 = data_g.loc[data.Confidence==1].Usefulness.tolist()
novelty_2 = data_g.loc[data.Confidence==2].Usefulness.tolist()
novelty_3 = data_g.loc[data.Confidence==3].Usefulness.tolist()
novelty_4 = data_g.loc[data.Confidence==4].Usefulness.tolist()
novelty_5 = data_g.loc[data.Confidence==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Confidence does influences Usefulness')

#####################################
### group Enjoyment vs Usefulness ###
#####################################
novelty_1 = data_g.loc[data.Anxiety==1].Usefulness.tolist()
novelty_2 = data_g.loc[data.Anxiety==2].Usefulness.tolist()
novelty_3 = data_g.loc[data.Anxiety==3].Usefulness.tolist()
novelty_4 = data_g.loc[data.Anxiety==4].Usefulness.tolist()
novelty_5 = data_g.loc[data.Anxiety==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Anxiety does influences Usefulness')
# Out:
# KruskalResult(statistic=2.8039752710576265, pvalue=0.5911467056575598)
# Enjoyment does influences Usefulness
# KruskalResult(statistic=4.257429712766779, pvalue=0.372286140624465)
# Boredom does influences Usefulness
# KruskalResult(statistic=5.497515988886519, pvalue=0.23994791241428431)
# Confidence does influences Usefulness
# KruskalResult(statistic=3.801809603449375, pvalue=0.4334919239537287)
# Anxiety does influences Usefulness

# %%
personalityS = data_s.loc[data.Personality=='S']
personalityC = data_s.loc[data.Personality=='C']
personalityI = data_s.loc[data.Personality=='I']
personalityD = data_s.loc[data.Personality=='D']

# %%
#######################################
### solo personality vs novelty ####
#######################################


result = stats.kruskal(personalityS.Novelty,personalityC.Novelty,personalityI.Novelty,personalityD.Novelty)
 
# Print the result
print(result)
print("personality does influence Novelty (solo)")

#######################################
### solo personality vs usefulness ####
#######################################


result = stats.kruskal(personalityS.Usefulness,personalityC.Usefulness,personalityI.Usefulness,personalityD.Usefulness)
 
# Print the result
print(result)
print("personality does influence Usefulness (solo)")
# Out:
# KruskalResult(statistic=0.8119750935450551, pvalue=0.8466006570244193)
# personality does influence Novelty (solo)
# KruskalResult(statistic=0.6409833890569387, pvalue=0.8869893465081948)
# personality does influence Usefulness (solo)

# %%
#####################################
### solo Emotion vs novelty ########
#####################################


#####################################
### solo Enjoyment vs novelty ######
#####################################
novelty_1 = data_s.loc[data.Enjoyment==1].Novelty.tolist()
novelty_2 = data_s.loc[data.Enjoyment==2].Novelty.tolist()
novelty_3 = data_s.loc[data.Enjoyment==3].Novelty.tolist()
novelty_4 = data_s.loc[data.Enjoyment==4].Novelty.tolist()
novelty_5 = data_s.loc[data.Enjoyment==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Enjoyment does not influences novelty')

#####################################
### solo Boredom vs novelty ######
#####################################
novelty_1 = data_s.loc[data.Boredom==1].Novelty.tolist()
novelty_2 = data_s.loc[data.Boredom==2].Novelty.tolist()
novelty_3 = data_s.loc[data.Boredom==3].Novelty.tolist()
novelty_4 = data_s.loc[data.Boredom==4].Novelty.tolist()
novelty_5 = data_s.loc[data.Boredom==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Boredom does influences novelty')


#####################################
### solo Enjoyment vs novelty ######
#####################################
novelty_1 = data_s.loc[data.Confidence==1].Novelty.tolist()
novelty_2 = data_s.loc[data.Confidence==2].Novelty.tolist()
novelty_3 = data_s.loc[data.Confidence==3].Novelty.tolist()
novelty_4 = data_s.loc[data.Confidence==4].Novelty.tolist()
novelty_5 = data_s.loc[data.Confidence==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Confidence does influences novelty')

#####################################
### solo Enjoyment vs novelty ######
#####################################
novelty_1 = data_s.loc[data.Anxiety==1].Novelty.tolist()
novelty_2 = data_s.loc[data.Anxiety==2].Novelty.tolist()
novelty_3 = data_s.loc[data.Anxiety==3].Novelty.tolist()
novelty_4 = data_s.loc[data.Anxiety==4].Novelty.tolist()
novelty_5 = data_s.loc[data.Anxiety==5].Novelty.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Anxiety does influences novelty')
# Out:
# KruskalResult(statistic=9.53484260651496, pvalue=0.04903621181648208)
# Enjoyment does not influences novelty
# KruskalResult(statistic=3.405149357769329, pvalue=0.49244634154887057)
# Boredom does influences novelty
# KruskalResult(statistic=4.506257110352679, pvalue=0.34180619306006593)
# Confidence does influences novelty
# KruskalResult(statistic=5.965055611813288, pvalue=0.20177318457105095)
# Anxiety does influences novelty

# %%
#####################################
### group Emotion vs Usefulness #####
#####################################


#####################################
### group Enjoyment vs Usefulness ###
#####################################
novelty_1 = data_s.loc[data.Enjoyment==1].Usefulness.tolist()
novelty_2 = data_s.loc[data.Enjoyment==2].Usefulness.tolist()
novelty_3 = data_s.loc[data.Enjoyment==3].Usefulness.tolist()
novelty_4 = data_s.loc[data.Enjoyment==4].Usefulness.tolist()
novelty_5 = data_s.loc[data.Enjoyment==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Enjoyment does influences Usefulness')

#####################################
### group Boredom vs Usefulness #####
#####################################
novelty_1 = data_s.loc[data.Boredom==1].Usefulness.tolist()
novelty_2 = data_s.loc[data.Boredom==2].Usefulness.tolist()
novelty_3 = data_s.loc[data.Boredom==3].Usefulness.tolist()
novelty_4 = data_s.loc[data.Boredom==4].Usefulness.tolist()
novelty_5 = data_s.loc[data.Boredom==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Boredom does influences Usefulness')


#####################################
### group Enjoyment vs Usefulness ###
#####################################
novelty_1 = data_s.loc[data.Confidence==1].Usefulness.tolist()
novelty_2 = data_s.loc[data.Confidence==2].Usefulness.tolist()
novelty_3 = data_s.loc[data.Confidence==3].Usefulness.tolist()
novelty_4 = data_s.loc[data.Confidence==4].Usefulness.tolist()
novelty_5 = data_s.loc[data.Confidence==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Confidence does influences Usefulness')

#####################################
### group Enjoyment vs Usefulness ###
#####################################
novelty_1 = data_s.loc[data.Anxiety==1].Usefulness.tolist()
novelty_2 = data_s.loc[data.Anxiety==2].Usefulness.tolist()
novelty_3 = data_s.loc[data.Anxiety==3].Usefulness.tolist()
novelty_4 = data_s.loc[data.Anxiety==4].Usefulness.tolist()
novelty_5 = data_s.loc[data.Anxiety==5].Usefulness.tolist()

result = stats.kruskal(novelty_1,novelty_2,novelty_3,novelty_4,novelty_5)
 
# Print the result
print(result)
print('Anxiety does influences Usefulness')
# Out:
# KruskalResult(statistic=5.3259627801659155, pvalue=0.2554562832260454)
# Enjoyment does influences Usefulness
# KruskalResult(statistic=1.7321754684997706, pvalue=0.7848649488772086)
# Boredom does influences Usefulness
# KruskalResult(statistic=7.832749562171615, pvalue=0.09790052613133521)
# Confidence does influences Usefulness
# KruskalResult(statistic=4.363401717955138, pvalue=0.3590531167710009)
# Anxiety does influences Usefulness
